# %%
import pandas as pd
import matplotlib as mlt
import seaborn as sns
from scipy import stats
import numpy as np

# %%
df = pd.read_csv('column_2C_weka.csv')
df
# Out:
#      pelvic_incidence  pelvic_tilt numeric  lumbar_lordosis_angle  \
# 0           63.027817            22.552586              39.609117
# 1           39.056951            10.060991              25.015378
# 2           68.832021            22.218482              50.092194
# 3           69.297008            24.652878              44.311238
# 4           49.712859             9.652075              28.317406
# ..                ...                  ...                    ...
# 305         47.903565            13.616688              36.000000
# 306         53.936748            20.721496              29.220534
# 307         61.446597            22.694968              46.170347
# 308         45.252792             8.693157              41.583126
# 309         33.841641             5.073991              36.641233
#
#      sacral_slope  pelvic_radius  degree_spondylolisthesis     class
# 0       40.475232      98.672917                 -0.254400  Abnormal
# ...

# %%
df['class'].value_counts()
# Out:
# Abnormal    210
# Normal      100
# Name: class, dtype: int64

# %%
df = pd.merge(df[df['class'] == 'Normal'], df[df['class'] == 'Abnormal'].sample(n=100), how='outer')
print(df['class'].value_counts())
# Out:
# Abnormal    100
# Normal      100
# Name: class, dtype: int64

# %%
sns.pairplot(df, hue='class', corner = True)

# %%
df = pd.read_csv('column_3C_weka.csv')
df
# Out:
#      pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0           63.027817    22.552586              39.609117     40.475232
# 1           39.056951    10.060991              25.015378     28.995960
# 2           68.832021    22.218482              50.092194     46.613539
# 3           69.297008    24.652878              44.311238     44.644130
# 4           49.712859     9.652075              28.317406     40.060784
# ..                ...          ...                    ...           ...
# 305         47.903565    13.616688              36.000000     34.286877
# 306         53.936748    20.721496              29.220534     33.215251
# 307         61.446597    22.694968              46.170347     38.751628
# 308         45.252792     8.693157              41.583126     36.559635
# 309         33.841641     5.073991              36.641233     28.767649
#
#      pelvic_radius  degree_spondylolisthesis   class
# ...

# %%
df['class'].value_counts()
# Out:
# Spondylolisthesis    150
# Normal               100
# Hernia                60
# Name: class, dtype: int64

# %%
df1 = pd.merge(df[df['class'] == 'Hernia'], df[df['class'] == 'Normal'].sample(n=60), how='outer')
df2 = df1.merge(df[df['class'] == 'Spondylolisthesis'].sample(n=60), how='outer')
print(df1['class'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-6ad8d5f1383a> in <module>
#       1 df1 = pd.merge(df[df['class'] == 'Hernia'], df[df['class'] == 'Normal'].sample(n=60), how='outer')
# ----> 2 df2 = df1.merge(df[df['class'] == 'Spondylolisthesis'].sample(n=60), how='outer')
#       3 print(df1['class'].value_counts())
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\generic.py in sample(self, n, frac, replace, weights, random_state, axis)
#    5348             )
#    5349
# -> 5350         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    5351         return self.take(locs, axis=axis)
#    5352
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken

# %%
sns.pairplot(df, hue='class', corner = True)

# %%
df = pd.read_csv('heart_failure_clinical_records_dataset.csv')
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
sns.pairplot(df, hue='DEATH_EVENT', corner = True)

# %%
df = pd.read_csv('heart.csv')
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
sns.pairplot(df, hue='target', corner = True)

# %%
df = pd.read_csv('breast-cancer-wisconsin.csv')
df
# Out:
#      Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 0                  5                        1                         1
# 1                  5                        4                         4
# 2                  3                        1                         1
# 3                  6                        8                         8
# 4                  4                        1                         1
# ..               ...                      ...                       ...
# 694                3                        1                         1
# 695                2                        1                         1
# 696                5                       10                        10
# 697                4                        8                         6
# 698                4                        8                         8
#
#      Marginal Adhesion   Single Epithelial Cell Size Bare Nuclei  \
# ...

# %%
sns.pairplot(df, hue='class', corner = True)

# %%
df = pd.read_csv('breastCancer.csv')
df
# Out:
#           id  clump_thickness  size_uniformity  shape_uniformity  \
# 0    1000025                5                1                 1
# 1    1002945                5                4                 4
# 2    1015425                3                1                 1
# 3    1016277                6                8                 8
# 4    1017023                4                1                 1
# ..       ...              ...              ...               ...
# 694   776715                3                1                 1
# 695   841769                2                1                 1
# 696   888820                5               10                10
# 697   897471                4                8                 6
# 698   897471                4                8                 8
#
#      marginal_adhesion  epithelial_size bare_nucleoli  bland_chromatin  \
# 0                    1                2             1                3
# ...

# %%
sns.pairplot(df, hue='class', corner=True)

# %%
df = pd.read_csv('data1.csv')
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
sns.pairplot(df, hue='diagnosis', corner=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-bbd2073ce2bb> in <module>
# ----> 1 sns.pairplot(df, hue='diagnosis', corner=True)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2030     if kind == "scatter":
# ...
